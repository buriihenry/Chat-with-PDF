# %%
import streamlit as st
from swarm import Swarm, Agent
from duckduckgo_search import DDGS
from datetime import datetime
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Use GPT-3.5-turbo model
MODEL = "gpt-3.5-turbo"

# Initialize Swarm client
client = Swarm()

# DuckDuckGo search instance
ddgs = DDGS()

# Function to search the web using DuckDuckGo
def search_web(query):
    print(f"Searching the web for {query}...")
    
    # DuckDuckGo search
    current_date = datetime.now().strftime("%Y-%m")
    results = ddgs.text(f"{query} {current_date}", max_results=10)
    if results:
        news_results = ""
        for result in results:
            news_results += f"Title: {result['title']}\nURL: {result['href']}\nDescription: {result['body']}\n\n"
        return news_results.strip()
    else:
        return f"Could not find news results for {query}."
    

# Define the Web Search Agent
web_search_agent = Agent(
    name="Web Search Assistant",
    instructions="Your role is to gather latest news articles on specified topics using DuckDuckGo's search capabilities.",
    functions=[search_web],
    model=MODEL
)

# Define the Research Analyst Agent
researcher_agent = Agent(
    name="Research Assistant",
    instructions="""Your role is to analyze and synthesize the raw search results. You should:
    1. Remove duplicate information and redundant content
    2. Identify and merge related topics and themes
    3. Verify information consistency across sources
    4. Prioritize recent and relevant information
    5. Extract key facts, statistics, and quotes
    6. Identify primary sources when available
    7. Flag any contradictory information
    8. Maintain proper attribution for important claims
    9. Organize information in a logical sequence
    10. Preserve important context and relationships between topics""",
    model=MODEL
)

# Define the Editor Agent
writer_agent = Agent(
    name="Writer Assistant",
    instructions="""Your role is to transform the deduplicated research results into a polished, publication-ready article. You should:
    1. Organize content into clear, thematic sections
    2. Write in a professional yet engaging tone
    3. Ensure proper flow between topics
    4. Add relevant context where needed
    5. Maintain factual accuracy while making complex topics accessible
    6. Include a brief summary at the beginning
    7. Format with clear headlines and subheadings
    8. Preserve all key information from the source material""",
    model=MODEL
)

# Workflow function to run the agents
def run_workflow(query):
    print("Running web research assistant workflow...")
    
    # Step 1: Web Search
    news_response = client.run(
        agent=web_search_agent,
        messages=[{"role": "user", "content": f"Search the web for {query}"}],
    )
    
    raw_news = news_response.messages[-1]["content"]

    # Step 2: Analyze and Synthesize the Search Results
    research_analysis_response = client.run(
        agent=researcher_agent,
        messages=[{"role": "user", "content": raw_news }],
    )

    deduplicated_news = research_analysis_response.messages[-1]["content"]
    
    # Step 3: Edit and Format the Analyzed Results
    publication_response = client.run(
        agent=writer_agent,
        messages=[{"role": "user", "content": deduplicated_news }],
    )
    
    return publication_response.messages[-1]["content"]

# Example usage
print(run_workflow("Latest news on LLMs and AI Agents"))
# Out:
# Running web research assistant workflow...
# Searching the web for Latest news on LLMs...
# Searching the web for Latest news on AI Agents...
# ## Emerging Trends in Large Language Models (LLMs) and AI Agents
#
# In the fast-evolving landscape of artificial intelligence, the latest advancements in Large Language Models (LLMs) and AI Agents are showcasing a shift towards practical applications and customization to meet industry needs. Let's delve into the recent developments shaping these technologies.
#
# ### Large Language Models: Enhancing Communication with DeepL Voice
# DeepL, a prominent player in language translation technology, recently unveiled DeepL Voice. This innovative service harnesses LLMs to provide real-time, text-based translations for voices and videos. By leveraging LLM capabilities, DeepL Voice offers seamless and accurate translations, bridging linguistic barriers and enabling efficient communication across diverse contexts.
#
# ### The Rise of Small Language Models (SLMs) in Conjunction with LLMs
# A noticeable trend in the AI landscape is the increasing utilization of Small Language Models (SLMs) alongside LLMs. This strategic pairing of large and small models is shaping various applications, highlighting the complementary roles these models play in enhancing efficiency and performance across different use cases. The synergy between SLMs and LLMs underscores a versatile approach to leveraging language processing capabilities effectively.
#
# ### Insights into Local LLMs: Understanding Functionality and Contextual Capabilities
# Recent insights have provided valuable perspectives on the operational dynamics of local LLMs. These revelations offer a deeper understanding of how these models function and shed light on the sizes of contexts they can proficiently manage. By unraveling the intricacies of local LLMs, researchers and developers can optimize their applications and tailor solutions to specific needs effectively.
#
# ### AI Agents: Tailored Solutions for Industry Challenges
# The landscape of AI agents is witnessing a transformative evolution, as highlighted by IDC's 2024 AI opportunity study. The report underscores a forthcoming trend where companies are poised to develop bespoke AI solutions, including custom AI agents, to address industry-specific challenges within the next 24 months. This strategic focus on tailored solutions signifies a paradigm shift towards customized AI applications crafted to meet precise industry requirements.
#
# ### Practical Applications of AI Agents: Automating Business Operations
# In a notable collaboration, Tribble and Box have integrated AI agents to streamline the Request for Proposal (RFP) process. This partnership exemplifies the real-world application of AI agents in automating complex business operations. By infusing AI-driven automation into the RFP process, organizations can enhance efficiency, accuracy, and decision-making, demonstrating the tangible benefits of leveraging AI agents in optimizing business workflows.
#
# ## Conclusion: Bridging Innovation and Industry Needs
# The latest advancements in LLMs and AI agents underscore a growing emphasis on practical applications, customization, and automation to address evolving industry demands. As technology continues to evolve, the synergy between large and small language models, alongside the advent of tailored AI solutions through AI agents, is poised to reshape how businesses communicate, operate, and innovate in the digital era. By embracing these transformative trends, organizations can unlock new opportunities for growth, efficiency, and competitive advantage in an increasingly AI-powered world.
